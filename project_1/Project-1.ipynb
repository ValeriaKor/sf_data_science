# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import math  #    необходима для логарифмирования

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
dst_database = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
display(dst_database.head(5))
display(dst_database.tail(5))
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
dst_database.info()

# Данные отсутствуют только в 3х столбцах
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
dst_database.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь

# Функция для извлечения сведений об образовании из столбца 'Образование и ВУЗ'
def get_edu_hei_inf(edu_hei):
    
    """Извлечение информации об уровне образования

    Args:
        edu_hei (str): значение столбца 'Образование и ВУЗ'

    Returns:
        str: уровень образования
                
    """
    
    list_splited = edu_hei.split(' ')  #    разделение строки по пробелу
    
    for i in range(3):  #    цикл по строго заданному (условие) возможному количеству значимых элементов
        
        if list_splited[i] == 'образование':  #    условие для обрезания списка
            edu = list_splited[:i]
            
    if len(edu) == 2:  #    если соискатель относится к категориям  'неоконченное высшее' и 'среднее специальное'
        str_edu = str(edu[0]) + ' ' + str(edu[1])
    else:
        str_edu = str(edu[0])  #    если соискатель относится к категориям  'высшее' и 'среднее'
    
    return str_edu     
               
dst_database['Образование'] = dst_database['Образование и ВУЗ'].apply(get_edu_hei_inf)  #    извлечение информации об образовании в новый столбец

dst_database['Образование'].unique()  #    визуализация полученных категорий
# Out:
# array(['Неоконченное высшее', 'Высшее', 'Среднее специальное', 'Среднее'],
#       dtype=object)

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь

# Функция для извлечения сведений о поле и возрасте из столбца 'Пол, возраст'
def get_sex_age(sex_age_date):
    
    """Извлечение информации о поле и возрасте

    Args:
        sex_age_date (str): значение столбца 'Пол, возраст'

    Returns:
        str: 'Ж' или 'М' в зависимости от пола
        int: возраст соискателя
                        
    """
    
    list_splited = sex_age_date.split(' , ')  #    разделение строки по запятой
    
    if list_splited[0] == 'Мужчина':  #    условие определения обозначения пола
        sex = 'М'
    else:
        sex = 'Ж'
    
    s = list_splited[1].strip()  #    удаление краевых пробелов
    slit_space = s.split(' ')  #    разделение стоки по пробелу  
    age_int = int(slit_space[0])  #    получение целочисленного значения возраста
    
    return sex, age_int

sex_age = dst_database['Пол, возраст'].apply(get_sex_age)  #    извлечение кортежа (пол, возраст)

# Размещение значений по столбцам 'Пол' и 'Возраст'
dst_database['Пол'] = sex_age.apply(lambda x: x[0])
dst_database['Возраст'] = sex_age.apply(lambda x: x[1])

# Визуализация полученных категорий (М,Ж) и значений (возраст)
display(dst_database['Пол'].unique())
display(dst_database['Возраст'].unique())
# Out:
# array(['М', 'Ж'], dtype=object)
# array([ 39,  60,  36,  38,  26,  29,  46,  34,  35,  59,  27,  21,  31,
#         37,  30,  33,  42,  32,  23,  28,  25,  24,  43,  53,  49,  44,
#         48,  54,  22,  20,  40,  62,  72,  45,  41,  61,  50,  58,  57,
#         52,  56,  18,  19,  51,  16,  47,  71,  63,  55,  64,  68,  17,
#         73,  66,  65,  77,  67,  69,  76,  70,  14,  15, 100], dtype=int64)

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь

experience_nan = dst_database['Опыт работы'].apply(lambda x: np.nan if x == 'Не указано' else x)  #    стандартизация обозначения пропусков

# Функция для извлечения опыта в месяцах из преобразованного столбца 'Опыт работы'
def experience_func(data):    
    
    """Извлечение информации о продолжительности опыта работы в месяцах

    Args:
        data (str): значение столбца 'Опыт работы'

    Returns:
        int: опыт работы в месяцах
        или
        np.nan: для пропущенных значений
                
    """
          
    split_list = str(data).split(' ')  #    разделение строки по пробелу
    split_list = split_list[2:]  #    удаление слов 'Опыт' и 'работы:'
    lim = 0  #    задаем переменную до цикла
        
    for i in range(len(split_list)):  #    цикл по индексам обрезанного списка
        
        if split_list[i] == '':  #    условие для нахождения необходимого предельного индекса
            lim = i
            break
    
    s = split_list[:lim]  #    обрезание списка по обнаруженному индексу
        
    if len(s) == 4:  #    для формата {месяц, год}
        return (int(int(s[0])*12 + int(s[2])))
    if len(s) == 2:  #    для формата {месяц} или {год}
        if s[1].startswith('мес'):  #    если по индексу [1] стоит элемент с корнем 'мес' 
            return int(s[0])
        else:  #    для формата {год}
            return int(int(s[0])*12)
    else:  #    для пропущенных значений
        return np.nan

# Извлечение информации в новый столбец и удаление сложного признака  
dst_database['Опыт работы (месяц)'] = experience_nan.apply(experience_func)  #    извлечение информации в новый столбец
dst_database.drop('Опыт работы', axis=1, inplace=True)

display(dst_database.head(3))  #    проверка результата
# Out:
#                                    Пол, возраст          ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982  20000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
# 1      Технический писатель
# 2                  Оператор
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь

# Функция для извлечения информации о городе из столбца 'Город, переезд, командировки'
def town_func(data):
    
    """Извлечение информации о городе

    Args:
        data (str): значение столбца 'Город, переезд, командировки'

    Returns:
        str: 'Москва', 'Санкт-Петербург', 'город-миллионник' или 'другие'
                        
    """
    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск',
                      'Самара', 'Ростов-на-Дону','Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]  #    список городов-миллионников
    
    split_list = data.split(' , ')  #    разделение строки по запятой
    
    if split_list[0] == 'Москва' or split_list[0] == 'Санкт-Петербург':  #    если первый элемент 'Москва' или 'Санкт-Петербург',
        return split_list[0]  #    возвращаем его
    
    elif split_list[0] in million_cities:  #    если первый элемент в списке городов-миллионников,
        return 'город-миллионник'  #    возвращаем категорию 'город-миллионник'
    
    else:  #    иначе возвращаем категорию 'другие'
        return 'другие'

# Функция для извлечения информации о переезде из столбца 'Город, переезд, командировки'
def relocate_func(data):
    
    """Извлечение информации о возможности переезда

    Args:
        data (str): значение столбца 'Город, переезд, командировки'

    Returns:
        bool: True - готов к переезду, False - не готов
                        
    """
    
    split_list = data.split(' , ')  #    разделение строки по запятой
    
    if split_list[1].startswith('м.'):  #    приведение к формату {город, переезд, командировки}
        split_list.pop(1)
    
    if 'не' in split_list[1]:  #    если второй элемент содержит частицу 'не',
        return False  #    возвращаем False
    else:  #    иначе - True
        return True

# Функция для извлечения информации о командировках из столбца 'Город, переезд, командировки'
def business_trip_func(data):
    
    """Извлечение информации о возможности командировок

    Args:
        data (str): значение столбца 'Город, переезд, командировки'

    Returns:
        bool: True - готов к командировкам, False - не готов
                        
    """
    
    split_list = data.split(' , ')  #    разделение строки по запятой
    
    if split_list[1].startswith('м.'):  #    приведение к формату {город, переезд, командировки}
        split_list.pop(1)
        
    if len(split_list) == 2:  #    если информация о командировках отсутствует,
        return False  #    возвращаем False
    
    if 'не' in split_list[2]:  #    если третий элемент содержит частицу 'не',
        return False  #    возвращаем False
    else:  #    иначе - True
        return True   

# Извлечение информации в новые столбцы и удаление сложного признака
dst_database['Город'] = dst_database['Город, переезд, командировки'].apply(town_func)
dst_database['Готовность к переезду'] = dst_database['Город, переезд, командировки'].apply(relocate_func)
dst_database['Готовность к командировкам'] = dst_database['Город, переезд, командировки'].apply(business_trip_func)
dst_database.drop('Город, переезд, командировки', axis=1, inplace=True)

display(dst_database.head(3))  #    проверка результата
# Out:
#                                    Пол, возраст          ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982  20000 руб.
#
#   Ищет работу на должность:  \
# 0   Системный администратор
# 1      Технический писатель
# 2                  Оператор
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
#
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь

# Списки категорий занятости и графика
employment_list = ['полная занятость','частичная занятость','проектная работа','волонтерство','стажировка']
schedule_list = ['полный день','сменный график','гибкий график','удалённая работа','вахтовый метод']

for i in employment_list:  #    цикл по элементам списка
    dst_database[i] = dst_database['Занятость'].apply(lambda x: True if i in x else False)  #    создаем новый признак
    
for j in schedule_list:  #    цикл по элементам списка
    dst_database[j] = dst_database['График'].apply(lambda x: True if j in x else False)  #    создаем новый признак

# Удаление сложных признаков
dst_database.drop('Занятость', axis=1, inplace=True)
dst_database.drop('График', axis=1, inplace=True)

display(dst_database.head(3))  #    проверка результата
# Out:
#                                    Пол, возраст          ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979  29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959  40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982  20000 руб.
#
#   Ищет работу на должность: Последнее/нынешнее место работы  \
# 0   Системный администратор         МАОУ "СОШ № 1 г.Немана"
# 1      Технический писатель    Временный трудовой коллектив
# 2                  Оператор                    ПАО Сбербанк
#
#                        Последняя/нынешняя должность  \
# 0                           Системный администратор
# 1  Менеджер проекта, Аналитик, Технический писатель
# 2                               Кассир-операционист
#
#                                    Образование и ВУЗ Обновление резюме  \
# 0  Неоконченное высшее образование 2000  Балтийск...  16.04.2019 15:59
# 1  Высшее образование 1981  Военно-космическая ак...  12.04.2019 08:42
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь

exchange_rates = pd.read_csv('data/ExchangeRates.csv', sep=',')  #    чтение таблицы с курсом валют

# Приведение признаков в формат 'Дата'
dst_database['Обновление резюме'] = pd.to_datetime(dst_database['Обновление резюме'], dayfirst=True).dt.date
exchange_rates['date'] = pd.to_datetime(exchange_rates['date'], dayfirst=True).dt.date

# Создание признака 'Сумма'
dst_currency_sum = dst_database['ЗП'].apply(lambda x: x.split(' '))
dst_database['Сумма'] = dst_currency_sum.apply(lambda x: x[0])

dst_currency = dst_currency_sum.apply(lambda x: x[1])  #    сохранение информации о валюте

# Функция для приведения названия валюты в формат ISO
def currency_ISO(currency):
        
    """Перевод названий валют в формат ISO

    Args:
        data (str): значение столбца 'Валюта'

    Returns:
        str: название  валюты в формате ISO
                        
    """

    currency_dict = {'руб.':'RUB', 'бел.руб.':'BYN', 'KZT':'KZT', 'EUR':'EUR', 'USD':'USD',
                        'грн.':'UAH','сум':'UZS', 'KGS':'KGS', 'AZN':'AZN'
       }  #    словарь обозначений ISO
       
    currency_ = currency_dict[currency]  #    вытаскивание значения из словаря
       
    return currency_  #    возвращаем название валюты в формате ISO

dst_database['Валюта'] = dst_currency.apply(currency_ISO)  #    создаем новый признак

# Объединяем таблицы по двум столбцам
merged_df = dst_database.merge(
        exchange_rates, 
        left_on=['Валюта', 'Обновление резюме'], 
        right_on=['currency', 'date'], 
        how='left')

# Заполнение образовавшихся NaN на 1 
merged_df['close'] = merged_df['close']. fillna(1)
merged_df['proportion'] = merged_df['proportion']. fillna(1)

merged_df['Сумма'] = merged_df['Сумма'].apply(lambda x: int(x))  #    приведение значений признака к целым числам

merged_df['ЗП (руб)'] = merged_df['Сумма'] * merged_df['close'] / merged_df['proportion']  #    создаение признака зарплаты в рублях
# Out:
# C:\Users\Валерия\AppData\Local\Temp\ipykernel_2328\2433677509.py:7: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Построение гистограммы и коробчатой диаграммы признака 'Возраст' рядом
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(10, 7))
axes[0].set_title('Распределение возраста соискателей hh.ru', fontsize=16)

sns.histplot(
    data=merged_df,
    x='Возраст',
    bins=50,
    kde=True,
    ax=axes[0]
);
sns.boxplot(
    data=merged_df,
    x='Возраст',
    orient='h',
    width=0.5
);

# Выведение значения моды и других статистик 
print(round(merged_df['Возраст'].mode()))
print(round(merged_df['Возраст'].describe()))
# Out:
# 0    30
# Name: Возраст, dtype: int64
# count    44744.0
# mean        32.0
# std          8.0
# min         14.0
# 25%         27.0
# 50%         31.0
# 75%         36.0
# max        100.0
# Name: Возраст, dtype: float64

# %% [markdown]
# ваши выводы по графику здесь
#
# Мода распределеия возраста равна 30 годам. Минимальный возраст соискателей: 14 лет, максимальный - 100. Возраст большинства соискателей находится в интервале от 27 до 36 лет. Судя по данным статистических выкладок и графикам наблюдается следующая аномалия для признака возраста: возраст одного из соискателей составляет 100 лет, вряд ли в таком возрасте ищут работу. С таким же сомнением можно отнестись и к значениям от 70 до 80 лет, однако они выглядят вполне реалистично, учитывая небольшое количество наблюдений в этой области.

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Построение гистограммы и коробчатой диаграммы признака 'Опыт работы (месяц)' рядом
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 4))
axes[0].set_title('Распределение опыта работы соискателей hh.ru', fontsize=16)
sns.histplot(
    data=merged_df,
    x='Опыт работы (месяц)',
    bins=35,
    kde=True,
    ax=axes[0]
);

sns.boxplot(
    data=merged_df,
    x='Опыт работы (месяц)',
    orient='h',
    width=0.3
);

# Выведение значения моды и других статистик
print(round(merged_df['Опыт работы (месяц)'].mode()))
print(round(merged_df['Опыт работы (месяц)'].describe()))
# Out:
# 0    81.0
# Name: Опыт работы (месяц), dtype: float64
# count    44574.0
# mean       114.0
# std         79.0
# min          1.0
# 25%         57.0
# 50%        100.0
# 75%        154.0
# max       1188.0
# Name: Опыт работы (месяц), dtype: float64

# %% [markdown]
# ваши выводы здесь
#
# Мода распределеия опыта работы равна 81 месяцу. Минимальный опыт работы: 1 месяц, максимальный - 1188. Опыт работы большинства соискателей находится в интервале от 57 до 154 месяцев. Судя по данным статистических выкладок и графикам наблюдается следующая аномалия для признака опыта работы: опыт одного из соискателей составляет 99 лет, таким образом, соискателю должно быть более ста лет, что противоречит предыдущим выводам, да и вообще, вряд ли эти данные корректны.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Построение гистограммы и коробчатой диаграммы признака 'ЗП (руб)' рядом
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 4))
axes[0].set_title('Распределение желаемой заработной платы соискателей hh.ru', fontsize=16)
sns.histplot(
    data=merged_df,
    x='ЗП (руб)',
    bins=100,
    kde=True,
    ax=axes[0],
    log_scale=True
);

sns.boxplot(
    data=merged_df,
    x='ЗП (руб)',
    orient='h',
    width=0.5
);

# Выведение статистических данных
print(round(merged_df['ЗП (руб)'].describe()))
# Out:
# count       44744.0
# mean        76534.0
# std        135932.0
# min             1.0
# 25%         37082.0
# 50%         59019.0
# 75%         95000.0
# max      24304876.0
# Name: ЗП (руб), dtype: float64

# %% [markdown]
# ваши выводы здесь
#
# Минимальная желаемая зарплата (ЖЗП): 1 рубль, максимальная - 24304876. ЖЗП большинства соискателей находится в интервале от 37082 до 95000 рублей. Судя по данным статистических выкладок и графикам наблюдается следующиее аномалии для признака ЖЗП: ЖЗП одного из соискателей составляет 1 рубль, вряд ли кто-то может прожить на такие деньги; ЖЗП другого соискателя составляет более 24 миллионов рублей, возможно, такие "зарплаты" есть, но вряд ли они официально зарегистрированы - это, скорее всего, ошибка или шутка. Сомнения также вызывает наблюдение ЖЗП около 750000, хотя такие ценные высокооплачиваемые специалисты вполне могут существовать.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Фильтрация по заработной плате, группировка по признаку 'Образование', получение медианной ЗП
bar_data = merged_df[merged_df['ЗП (руб)']<1000000].groupby(
    ['Образование'],
    as_index=False
)['ЗП (руб)'].median()

# Построение столбчатой диаграммы признака 'ЗП (руб)' в зависимости от уровня образования
fig = px.bar(
    data_frame=bar_data,
    x='Образование',
    y='ЗП (руб)',
    title='Медианная ЗП по уровню образования'
)
fig.show()

# %% [markdown]
# ваши выводы здесь
#
# Как видно из графика, медианная желаемая заработная плата максимальна среди анкет людей с высшим образованием, минимальна - среди анкет людей со средним специальным и средним образованием. Очевидно, что человек с высшим образованием больше ценит себя как сотрудника.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь

box_data = merged_df[merged_df['ЗП (руб)']<1000000]  #    фильтрация признака 'ЗП (руб)'

# Построение диаграммы распределения признака 'ЗП (руб)' в зависимости от города
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 4))
axes.set_title('Распределение ЗП в зависимости от города', fontsize=16)
fig = sns.boxplot(
    data=box_data,
    y='Город',
    x='ЗП (руб)',
    orient='h',
    width=0.9
);

# %% [markdown]
# ваши выводы здесь
#
# Исходя из рисунка можно предположить, что чем больше медианная ЗП, тем больше размах. Безусловно, признак города очень важен при прогнозировании зарплаты, особенно в случае с Москвой и Санкт-Петербургом.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь

# Группировка по признакам 'Готовность к командировкам' и 'Готовность к переезду'; получение медианной ЗП
bar_data = merged_df.groupby(
    ['Готовность к командировкам', 'Готовность к переезду'],
    as_index=False
)['ЗП (руб)'].median()

# Построение многоуровневой столбчатой диаграммы признака 'ЗП (руб)' в зависимости от готовности к переезду и командировкам
fig = px.bar(
    data_frame=bar_data,
    y='Готовность к переезду',
    x='ЗП (руб)',
    barmode='group',
    color='Готовность к командировкам',
    orientation='h',
    title='Зависимость медианной ЗП от готовности к переезду и командировкам'
)
fig.show()

# %% [markdown]
# ваши выводы здесь
#
# Из диаграммы видно, что соискатели, которые не готовы к переездам и командировкам, рассчитывают на более низкую ЗП, чуть больше просят люди, готовые только к командировкам. Соискатели, которые готовы только к переезду и к переезду и командировкам, одинаково оценивают свой труд. Видимо, это происходит из-за того, что переезд - это куда более трудное мероприятие, чем командировка.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь

# Построение сводной таблицы медианной ЗП в зависимости от возраста и образования
pivot = merged_df.pivot_table(
    'ЗП (руб)',
    index='Возраст',
    columns='Образование',
    aggfunc='median'
)

# Построение тепловой карты медианных значений ЗП
heatmap = sns.heatmap(data=pivot, cmap='YlGnBu')
heatmap.set_title('Тепловая карта медианной ЗП', fontsize=16);

# %% [markdown]
# ваши выводы здесь
#
# Из тепловой катры видно, 1) что от высшего образования к специальному ЗП падает; 2) соискатели с высшим образованием распределены от 14 до 76 лет распределены по ЗП более-менее равномерно, заметен провал ЗП в период с 18 до 23 лет (работа во  воремя учебы), вундеркинды с 14 до 17 лет просят высокий заработок; 3) соискатели с неоконченным высшим образованием распеделены от 17 до 62 лет, спад ЗП с 17 до 23 лет и после 60; 4) соискатели со средним образованием от 17 до 56 лет распределены по ЗП более-менее равномерно; 5) для соискателей со средним специальным образованием распределение выглядит еще более равномерным (исключая выбросы). Примечательно, что верхняя граница возрастов в разных группах по образованию разная. Возможно из-за того, чтол люди с высшим образованием в среднем живут дольше, а может из-за того, что рабочие профессии более стабильны в отношении места работы.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь

merged_df['Опыт работы (год)'] = merged_df['Опыт работы (месяц)'] / 12  #    создание нового признака (временно)

# Построение диаграммы рассеяния (зависимость опыта работы от возраста)
fig, ax = plt.subplots(figsize=(20, 5))
ax.scatter(x=merged_df['Возраст'] , y=merged_df['Опыт работы (год)'])
plt.xlabel('Опыт работы (год)')
plt.ylabel("Возраст")
plt.plot([0, 100], [0, 100], color='red')  #    проведение прямой y=x
plt.title('Зависимость опыта работы от возраста') 
plt.show()

# Выявление количества точек аномалий
print(merged_df[merged_df['Возраст'] < merged_df['Опыт работы (год)']]['Возраст'].count())
print(merged_df[merged_df['Возраст'] == merged_df['Опыт работы (год)']]['Возраст'].count())
# Out:
# 7
# 0

# %% [markdown]
# ваши выводы здесь
#
# 7 точк лежат выше прямой, что характеризует их как выбросы.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

filtered_exp = merged_df[merged_df['Опыт работы (год)'] < 60]  #    ограничение признака 'Опыт работы (год)'

# Построение коробчатой диаграммы признака 'Опыт работы (год)' в зависимости от пола
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(10, 4))
axes.set_title('Распределение опыта работы в зависимости от пола', fontsize=16)
sns.boxplot(
    data=filtered_exp,
    y='Пол',
    x='Опыт работы (год)',
    orient='h',
    width=0.9
);

# Выведение статистических выкладок
print(filtered_exp[filtered_exp['Пол'] == 'Ж']['Опыт работы (год)'].describe())
print(filtered_exp[filtered_exp['Пол'] == 'М']['Опыт работы (год)'].describe())
# Out:
# count    8500.000000
# mean        8.277000
# std         5.852204
# min         0.083333
# 25%         4.000000
# 50%         7.083333
# 75%        11.166667
# max        48.833333
# Name: Опыт работы (год), dtype: float64
# count    36073.000000
# mean         9.828838
# std          6.698405
# min          0.083333
# 25%          4.916667
# 50%          8.583333
# 75%         13.333333
# max         55.250000
# Name: Опыт работы (год), dtype: float64

# %% [markdown]
# ваши выводы здесь
#
# Исходя из графика 1 в среднем (медиана) среди соискателей hh.ru опыт работы у мужчин (7.08±5.85) больше, чем у женщин (8.58±6.70) (но, исходя из вида распределения и стандартного отклонения, различия не значительны), максимальные значения опыта в годах также больше у мужчин.

# %%
# ваш код здесь

# Группировка по столбцу 'Образование', получение доли соискателей, готовых к волотнерству
grouped_df = merged_df.groupby(['Образование'])['волонтерство'].mean()

# Построение столбчатой диаграммы доли соискателей, готовых к волотнерству, в зависимости от образзования
grouped_df.plot(
    kind='bar',
    grid=True,
    figsize=(12, 4),
    colormap='plasma',
    title='Доля соискателей с определенным уровнем образования, готовых к волонтерству',
);

# %% [markdown]
# ваши выводы здесь
#
# Среди людей с высшим обращованием, наименьшая доля людей, готовых к волонтерству , среди людей со средним образованием - наибольшая. Можно сделать вывод о том, что люди с высшим образованием не склонны к волонтерству.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь

print(merged_df.shape[0])  #    отображение количества строк

merged_df= merged_df.drop_duplicates()  #    удаление полных дубликатов

print(merged_df.shape[0])  #    отображение количества строк после удаления
# Out:
# 44744
# 44583

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь

merged_df.isnull().sum()  #    информация о числе пропусков
# Out:
# Пол, возраст                           0
# ЗП                                     0
# Ищет работу на должность:              0
# Последнее/нынешнее место работы        1
# Последняя/нынешняя должность           2
# Образование и ВУЗ                      0
# Обновление резюме                      0
# Авто                                   0
# Образование                            0
# Пол                                    0
# Возраст                                0
# Опыт работы (месяц)                  168
# Город                                  0
# Готовность к переезду                  0
# Готовность к командировкам             0
# полная занятость                       0
# частичная занятость                    0
# проектная работа                       0
# волонтерство                           0
# стажировка                             0
# полный день                            0
# сменный график                         0
# гибкий график                          0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь

cleaned_df = merged_df  #    копия таблицы

# Определение индексов строк с пустыми значениями в признаке 'Последнее/нынешнее место работы'
null_data = cleaned_df['Последнее/нынешнее место работы'].isnull()
cols_with_null = null_data[null_data > 0].index

cleaned_df = cleaned_df.drop(cols_with_null)  #    удаление строк с пустыми значениями в признаке 'Последнее/нынешнее место работы'

# Определение индексов строк с пустыми значениями в признаке 'Последняя/нынешняя должность'
null_data = cleaned_df['Последняя/нынешняя должность'].isnull()
cols_with_null = null_data[null_data > 0].index

cleaned_df = cleaned_df.drop(cols_with_null)  #    удаление строк с пустыми значениями в признаке 'Последняя/нынешняя должность'

# Заполнение пустых значений признака 'Опыт работы (месяц)' медианным значением
cleaned_df= cleaned_df.fillna( {'Опыт работы (месяц)':cleaned_df['Опыт работы (месяц)'].median()})

print(cleaned_df.shape[0])  #    выведение количества строк
# Out:
# 44581

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь

out = cleaned_df[(cleaned_df['ЗП (руб)'] > 1000000) | (cleaned_df['ЗП (руб)'] < 1000)]  #    аутлаеры, оставшиеся после фильтрации ЗП

cleaned_df = cleaned_df.drop(out.index)  #    удаление аутлаеров по индексу

print(cleaned_df.shape[0])  #    выведение количества строк
# Out:
# 44492

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь

out = cleaned_df[cleaned_df['Опыт работы (год)'] > cleaned_df['Возраст']]  #    аутлаеры, оставшиеся после фильтрации опыта и возраста

cleaned_df = cleaned_df.drop(out.index)  #    удаление аутлаеров по индексу

print(cleaned_df.shape[0])  #    выведение количества строк
# Out:
# 44485

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь

# Построение гистограммы рраспределения возраста в логарифмическом масштабе
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
log_age = cleaned_df['Возраст'].apply(lambda x: math.log(x))
histplot = sns.histplot(log_age, bins=30, ax=ax)
# Отображение среднего и границ интервала трех сигм
histplot.axvline(log_age.mean(), color='k', lw=2)
histplot.axvline(log_age.mean()+ 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.axvline(log_age.mean()- 3 * log_age.std(), color='k', ls='--', lw=2)
histplot.set_title('Распределение возраста в логарифмическом масштабе');

print(f'Численный показатель ассиметрии: {log_age.skew()}')  #    численный показатель ассиметрии

# Функция определения числа выбросов  по методу z-отклонения и результирующего числа записей
def outliers_z_score_mod(data, feature, log_scale=False, left=3, right=3):
    
    """Определение числа выбросов о методу z-отклонения и результирующего числа записей

    Args:
        data (pandas.DataFrame): таблица
        feature (str): название столбца
        log_scale (bool, optional): применение логарифмической шкалы. По умолчанию False - логарифмирование не применяется
        left (int, optional): количество сигм слева. По умолчанию 3
        right (int, optional): количество сигм справа. По умолчанию 3

    Returns:
        pandas.DataFrame: наблюдения, попавшие в разрад выбросов
        pandas.DataFrame: очищенные данные, из которых исключены выбросы
                                
    """
    
    # Условие преобразования значений столбца (логарифмировать или нет)
    if log_scale:
        x = np.log(data[feature])
    else:
        x = data[feature]
        
    mu = x.mean()  #    среднее значение по столбцу
    sigma = x.std()  #    определение значения сигмы
    
    # Определение  нижне    й и верзней границы
    lower_bound = mu - left * sigma
    upper_bound = mu + right * sigma
    
    # Определение аутлаеров и результирующего числа записей
    outliers = data[(x < lower_bound) | (x > upper_bound)]
    cleaned = data[(x >= lower_bound) & (x <= upper_bound)]
    
    return outliers, cleaned  #    возвращаем значения

outliers, cleaned = outliers_z_score_mod(cleaned_df, 'Возраст', log_scale=True, left=3, right=4)  #   аутлаеры и результирующкк число записей

# Выведение полученных значений
print(f'Число выбросов по методу z-отклонения: {outliers.shape[0]}')
print(f'Результирующее число записей: {cleaned.shape[0]}')
display(outliers)
# Out:
# Численный показатель ассиметрии: 0.4523422276053838
# Число выбросов по методу z-отклонения: 3
# Результирующее число записей: 44482
#                                      Пол, возраст          ЗП  \
# 31137     Мужчина ,  15 лет , родился 11 мая 2004  10000 руб.
# 32950     Мужчина ,  15 лет , родился 1 июня 2003   2000 руб.
# 33654  Мужчина ,  100 лет , родился 1 января 1919  60000 руб.
#
#             Ищет работу на должность: Последнее/нынешнее место работы  \
# 31137  Менеджер по работе с клиентами           ООО "ФёрстКэшКомпани"
# 32950                 Тестировщик игр                        OOO ЖМЫХ
# 33654            Frontend-разработчик                       Freelance
#
#          Последняя/нынешняя должность  \
# 31137  Менеджер по работе с клиентами
# 32950                  Тестировщик ПО
# 33654            Frontend-разработчик
#
#                                        Образование и ВУЗ Обновление резюме  \
# ...

# %% [markdown]
# ваш коммментарий здесь
#
# На графике наблюдается правая ассиметрия: хвост распределения направлен в правую сторону, численный показатель асимметрии skew()>0. Методом z-отклонения (с послаблением на 1 сигму вправо) под категорию выброса попали соискатели возрастом 15 лет (2) и 100 лет (1).
